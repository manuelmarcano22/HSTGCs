# %%
import pandas as pd
from astropy.time import Time
import numpy as np
from tabulate import tabulate

# %%
data = pd.read_csv('M22.csv',low_memory=False)

# %%
data = data.drop(data.index[0])
#m4data
data['YearDay'] = data['Start Time'].map(lambda times: '.'.join(Time(times).yday.split(':',2)[:2]))

data['Week'] = data['Start Time'].map(lambda times: int(np.floor(float(Time(times).yday.split(':')[1])/7.)))
t =data.groupby(['Filters/Gratings','Instrument','Exp Time','Proposal ID']).size().reset_index().rename(columns={0:'ocurrence'})
t.sort_values(by=['ocurrence'],ascending=False)
# Out:
#    Filters/Gratings Instrument  Exp Time Proposal ID  ocurrence
# 31            F814W     WFPC2    260.000        7615        192
# 22            F606W     WFPC2    260.000        7615         72
# 20            F555W     WFPC2     26.000        8174         12
# 28           F785LP     WFPC2     26.000        8174         11
# 30            F814W     WFPC2    100.000       11233          9
# 13            F450W     WFPC2    350.000       11233          9
# 29            F814W     WFC3      50.000       12311          4
# 4             F275W     WFC3    2436.000       12311          4
# 7             F336W     WFPC2    350.000       11975          3
# 19            F555W     WFPC2     10.000       11975          3
# 2             F255W     WFPC2    700.000       11975          3
# 1             F170W     WFPC2    700.000       11975          3
# 24            F656N     WFPC2   1100.000        5344          3
# 3             F255W     WFPC2    800.000       10524          2
# 15            F502N     WFPC2    900.000        5404          2
# 12            F439W     WFPC2    400.000        5344          2
# 27            F675W     WFPC2    100.000        5344          2
# 25            F656N     WFPC2    120.000        5344          1
# 23    F606W;CLEAR2L     ACS      223.000       10775          1
# 21            F555W     WFPC2     30.000       10524          1
# 26            F675W     WFPC2     10.000        5344          1
# 0     CLEAR1L;F814W     ACS      263.000       10775          1
# 18            F555W     WFPC2      0.500       11975          1
# 17            F547M     WFC3     299.000       12193          1
# 14            F467M     WFC3    1456.000       12193          1
# 11            F439W     WFPC2     40.000        5344          1
# 10            F438W     WFC3     282.000       13297          1
# 9             F395N     WFC3    2656.000       12193          1
# 8             F336W     WFPC2    500.000       10524          1
# 6             F336W     WFPC2     14.000       11975          1
# 5             F336W     WFC3    1901.000       13297          1
# 16    F502N;CLEAR2L     ACS     5306.000       11558          1

# %%
print(tabulate(t.sort_values(by=['ocurrence'],ascending=False), tablefmt="pipe", headers="keys"))
# Out:
# |    | Filters/Gratings   | Instrument   |   Exp Time |   Proposal ID |   ocurrence |
# |---:|:-------------------|:-------------|-----------:|--------------:|------------:|
# | 31 | F814W              | WFPC2        |      260   |          7615 |         192 |
# | 22 | F606W              | WFPC2        |      260   |          7615 |          72 |
# | 20 | F555W              | WFPC2        |       26   |          8174 |          12 |
# | 28 | F785LP             | WFPC2        |       26   |          8174 |          11 |
# | 30 | F814W              | WFPC2        |      100   |         11233 |           9 |
# | 13 | F450W              | WFPC2        |      350   |         11233 |           9 |
# | 29 | F814W              | WFC3         |       50   |         12311 |           4 |
# |  4 | F275W              | WFC3         |     2436   |         12311 |           4 |
# |  7 | F336W              | WFPC2        |      350   |         11975 |           3 |
# | 19 | F555W              | WFPC2        |       10   |         11975 |           3 |
# |  2 | F255W              | WFPC2        |      700   |         11975 |           3 |
# |  1 | F170W              | WFPC2        |      700   |         11975 |           3 |
# | 24 | F656N              | WFPC2        |     1100   |          5344 |           3 |
# |  3 | F255W              | WFPC2        |      800   |         10524 |           2 |
# | 15 | F502N              | WFPC2        |      900   |          5404 |           2 |
# | 12 | F439W              | WFPC2        |      400   |          5344 |           2 |
# | 27 | F675W              | WFPC2        |      100   |          5344 |           2 |
# | 25 | F656N              | WFPC2        |      120   |          5344 |           1 |
# | 23 | F606W;CLEAR2L      | ACS          |      223   |         10775 |           1 |
# | 21 | F555W              | WFPC2        |       30   |         10524 |           1 |
# | 26 | F675W              | WFPC2        |       10   |          5344 |           1 |
# |  0 | CLEAR1L;F814W      | ACS          |      263   |         10775 |           1 |
# | 18 | F555W              | WFPC2        |        0.5 |         11975 |           1 |
# | 17 | F547M              | WFC3         |      299   |         12193 |           1 |
# | 14 | F467M              | WFC3         |     1456   |         12193 |           1 |
# | 11 | F439W              | WFPC2        |       40   |          5344 |           1 |
# | 10 | F438W              | WFC3         |      282   |         13297 |           1 |
# |  9 | F395N              | WFC3         |     2656   |         12193 |           1 |
# |  8 | F336W              | WFPC2        |      500   |         10524 |           1 |
# |  6 | F336W              | WFPC2        |       14   |         11975 |           1 |
# |  5 | F336W              | WFC3         |     1901   |         13297 |           1 |
# | 16 | F502N;CLEAR2L      | ACS          |     5306   |         11558 |           1 |

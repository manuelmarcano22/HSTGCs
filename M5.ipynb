# %%
import pandas as pd
from astropy.time import Time
import numpy as np
from tabulate import tabulate

# %%
data = pd.read_csv('M5.csv',low_memory=False)

# %%
data = data.drop(data.index[0])
#m4data
data['YearDay'] = data['Start Time'].map(lambda times: '.'.join(Time(times).yday.split(':',2)[:2]))

data['Week'] = data['Start Time'].map(lambda times: int(np.floor(float(Time(times).yday.split(':')[1])/7.)))
t =data.groupby(['Filters/Gratings','Instrument','Exp Time','Proposal ID']).size().reset_index().rename(columns={0:'ocurrence'})
t.sort_values(by=['ocurrence'],ascending=False)
# Out:
#    Filters/Gratings Instrument  Exp Time Proposal ID  ocurrence
# 19            F555W     WFPC2     10.000       11077         14
# 20            F555W     WFPC2    100.000       11077          6
# 4     CLEAR1L;F435W     ACS      680.000       10615          5
# 36            F814W     WFC3     700.000       12517          4
# 25            F555W     WFPC2    400.000       11077          4
# 27            F606W     WFC3     700.000       12517          4
# 14            F390W     WFC3     735.000       12517          4
# 23            F555W     WFPC2     30.000        6607          3
# 1     CLEAR1L;F435W     ACS     1235.000       10615          3
# 12            F336W     WFPC2    400.000        6607          3
# 8             F255W     WFPC2   1300.000        6607          3
# 11            F336W     WFC3     612.000       13297          2
# 7            F160BW     WFPC2    500.000        6607          2
# 17            F439W     WFPC2    100.000        8118          2
# 21            F555W     WFPC2      3.000        6607          2
# 24            F555W     WFPC2     30.000        8118          2
# 30            F656N     WFC3    5250.000       11615          1
# 31            F656N     WFPC2    200.000        5865          1
# 29    F625W;CLEAR2L     ACS      300.000       10120          1
# 28    F606W;CLEAR2L     ACS      567.000       10775          1
# 32            F656N     WFPC2    300.000        5865          1
# 33    F658N;CLEAR2L     ACS     1080.000       10120          1
# 34    F658N;CLEAR2L     ACS      680.000       10120          1
# 26            F606W     WFC3     600.000       11615          1
# 35            F814W     WFC3     600.000       11615          1
# 0     CLEAR1L;F435W     ACS     1150.000       10615          1
# 22            F555W     WFPC2      3.000        8118          1
# 16            F438W     WFC3      59.000       13297          1
# 15            F438W     WFC3      58.000       13297          1
# 13            F390W     WFC3    3000.000       11615          1
# 10            F275W     WFC3    1380.000       13297          1
# 9             F275W     WFC3    1378.000       13297          1
# 6     CLEAR1L;F814W     ACS      567.000       10775          1
# 5     CLEAR1L;F435W     ACS       70.000       10120          1
# 3     CLEAR1L;F435W     ACS      680.000       10120          1
# 2     CLEAR1L;F435W     ACS     1260.000       10615          1
# 18            F439W     WFPC2     40.000        8118          1

# %%
print(tabulate(t.sort_values(by=['ocurrence'],ascending=False), tablefmt="pipe", headers="keys"))
# Out:
# |    | Filters/Gratings   | Instrument   |   Exp Time |   Proposal ID |   ocurrence |
# |---:|:-------------------|:-------------|-----------:|--------------:|------------:|
# | 19 | F555W              | WFPC2        |         10 |         11077 |          14 |
# | 20 | F555W              | WFPC2        |        100 |         11077 |           6 |
# |  4 | CLEAR1L;F435W      | ACS          |        680 |         10615 |           5 |
# | 36 | F814W              | WFC3         |        700 |         12517 |           4 |
# | 25 | F555W              | WFPC2        |        400 |         11077 |           4 |
# | 27 | F606W              | WFC3         |        700 |         12517 |           4 |
# | 14 | F390W              | WFC3         |        735 |         12517 |           4 |
# | 23 | F555W              | WFPC2        |         30 |          6607 |           3 |
# |  1 | CLEAR1L;F435W      | ACS          |       1235 |         10615 |           3 |
# | 12 | F336W              | WFPC2        |        400 |          6607 |           3 |
# |  8 | F255W              | WFPC2        |       1300 |          6607 |           3 |
# | 11 | F336W              | WFC3         |        612 |         13297 |           2 |
# |  7 | F160BW             | WFPC2        |        500 |          6607 |           2 |
# | 17 | F439W              | WFPC2        |        100 |          8118 |           2 |
# | 21 | F555W              | WFPC2        |          3 |          6607 |           2 |
# | 24 | F555W              | WFPC2        |         30 |          8118 |           2 |
# | 30 | F656N              | WFC3         |       5250 |         11615 |           1 |
# | 31 | F656N              | WFPC2        |        200 |          5865 |           1 |
# | 29 | F625W;CLEAR2L      | ACS          |        300 |         10120 |           1 |
# | 28 | F606W;CLEAR2L      | ACS          |        567 |         10775 |           1 |
# | 32 | F656N              | WFPC2        |        300 |          5865 |           1 |
# | 33 | F658N;CLEAR2L      | ACS          |       1080 |         10120 |           1 |
# | 34 | F658N;CLEAR2L      | ACS          |        680 |         10120 |           1 |
# | 26 | F606W              | WFC3         |        600 |         11615 |           1 |
# | 35 | F814W              | WFC3         |        600 |         11615 |           1 |
# |  0 | CLEAR1L;F435W      | ACS          |       1150 |         10615 |           1 |
# | 22 | F555W              | WFPC2        |          3 |          8118 |           1 |
# | 16 | F438W              | WFC3         |         59 |         13297 |           1 |
# | 15 | F438W              | WFC3         |         58 |         13297 |           1 |
# | 13 | F390W              | WFC3         |       3000 |         11615 |           1 |
# | 10 | F275W              | WFC3         |       1380 |         13297 |           1 |
# |  9 | F275W              | WFC3         |       1378 |         13297 |           1 |
# |  6 | CLEAR1L;F814W      | ACS          |        567 |         10775 |           1 |
# |  5 | CLEAR1L;F435W      | ACS          |         70 |         10120 |           1 |
# |  3 | CLEAR1L;F435W      | ACS          |        680 |         10120 |           1 |
# |  2 | CLEAR1L;F435W      | ACS          |       1260 |         10615 |           1 |
# | 18 | F439W              | WFPC2        |         40 |          8118 |           1 |
